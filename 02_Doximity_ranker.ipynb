# %% [markdown]
# # **02 Doximity Ranker**

# %%
# Importing required packages
import os
import glob
import requests
import re
import pandas as pd
pd.set_option('max_colwidth', 400)  #wider pandas columns upon render
import numpy as np
from bs4 import BeautifulSoup
from itertools import islice
import thefuzz
from thefuzz import fuzz, process
from datetime import date
import sklearn

# Printing the working directory
os.getcwd()
# Out:
# '/home/toofastdan/Documents/APSA/2024-07-29_Texas-STAR'

# %%
# Finding out package versions
print(f"Pandas version: {pd.__version__}")
print(f"thefuzz version: {thefuzz.__version__}")
print(f"Scikit-learn version: {sklearn.__version__}")
# Out:
# Pandas version: 2.2.3
# thefuzz version: 0.22.1
# Scikit-learn version: 1.6.0

# %% [markdown]
# ### **Defining Functions for Parsing Doximity rank list html files**

# %%
def parse_dox(filename):
    with open(filename, 'r', encoding='utf-8') as file:
        soup = BeautifulSoup(file, "html.parser")
    return soup

# %%
def residency_parser(file):
    # Beautiful Soup
    soup = parse_dox(filename=file)
    
    # Extracting the residency list div from the page
    res_list = soup.find("div", class_ = "residency-program-list")
    
    # Program names
    programs = res_list.find_all("a", class_ = "residency-result-program-title")
    programs = [p.text for p in programs]

    # Program locations
    locations = res_list.find_all("p", class_ = "residency-result-location")
    locations = [l.text for l in locations]

    # Program Sizes
    program_size = res_list.find_all("p", class_ = "residency-result-stats-program-size")
    program_size = [ps.text for ps in program_size]
    pattern = r'\d+'
    program_size = [int(re.findall(pattern, ps)[0]) for ps in program_size]

    # Program ranks
    ranks = np.arange(1, len(programs) + 1, 1)
    
    # Making a dataframe
    df = pd.DataFrame({"program": programs, "location": locations, "program_size": program_size, "rank": ranks})
    return df

# %% [markdown]
# ### **Parsing all doximity html files**

# %%
# Getting all .html files from residency rankings from doximity
html_list = glob.glob("dox_rankings/*.html")
html_list[10:13]
# Out:
# ['dox_rankings\\Internal Medicine-Pediatrics_research-output.html',
#  'dox_rankings\\Internal Medicine_reputation.html',
#  'dox_rankings\\Internal Medicine_research-output.html']

# %%
# Looping over each file to get rankings
df_list = []
for h in html_list:
    # Getting specialty and sort metrics from the html file names
    file_name = h.replace("dox_rankings\\", "").replace(".html", "")
    specialty, sort_by = file_name.split("_")
    
    # Beatiful Soup parsing
    print(specialty, sort_by)
    df = residency_parser(file=h)
    df["specialty"] = specialty
    df["sort_by"] = sort_by
    df_list.append(df)
    
# Concatenating things to a single dataframe
df_complete = pd.concat(df_list)
df_complete
# Out:
# Anesthesiology reputation
# Anesthesiology research-output
# Child Neurology reputation
# Child Neurology research-output
# Dermatology reputation
# Dermatology research-output
# Emergency Medicine reputation
# Emergency Medicine research-output
# Family Medicine reputation
# Internal Medicine-Pediatrics reputation
# Internal Medicine-Pediatrics research-output
# Internal Medicine reputation
# Internal Medicine research-output
# Neurological Surgery reputation
# Neurological Surgery research-output
# Neurology reputation
# Neurology research-output
# Nuclear Medicine reputation
# Nuclear Medicine research-output
# Obstetrics and Gynecology reputation
# Obstetrics and Gynecology research-output
# Occupational Medicine reputation
# Occupational Medicine research-output
# Ophthalmology reputation
# Ophthalmology research-output
# Orthopaedic Surgery reputation
# Orthopaedic Surgery research-output
# Otolaryngology reputation
# Otolaryngology research-output
# Pathology reputation
# Pathology research-output
# Pediatrics-Medical Genetics size-of-program
# Pediatrics reputation
# Pediatrics research-output
# Physical Medicine and Rehabilitation reputation
# Physical Medicine and Rehabilitation research-output
# Plastic Surgery reputation
# Plastic Surgery research-output
# Preventive Medicine size-of-program
# Psychiatry reputation
# Psychiatry research-output
# Radiation Oncology reputation
# Radiation Oncology research-output
# Radiology-Diagnostic reputation
# Radiology-Diagnostic research-output
# Radiology-Interventional size-of-program
# Surgery reputation
# Surgery research-output
# Thoracic Surgery size-of-program
# Urology reputation
# Urology research-output
# Vascular Surgery size-of-program
#                                               program       location  \
# 0   Mass General Brigham/Massachusetts General Hos...         Boston
# 1            University of California (San Francisco)  San Francisco
# 2   Stanford Health Care-Sponsored Stanford Univer...       Stanford
# 3   Mass General Brigham/Brigham and Women's Hospital         Boston
# 4                            Duke University Hospital         Durham
# ..                                                ...            ...
# 72      Wake Forest University Baptist Medical Center  Winston Salem
# 73         Washington University/B-JH/SLCH Consortium    Saint Louis
# 74                      Yale-New Haven Medical Center      New Haven
# 75     Zucker School of Medicine at Hofstra/Northwell  New Hyde Park
# 76  Zucker School of Medicine at Hofstra/Northwell...       New York
#
#     program_size  rank         specialty          sort_by
# 0            116     1    Anesthesiology       reputation
# 1             96     2    Anesthesiology       reputation
# 2            108     3    Anesthesiology       reputation
# 3            128     4    Anesthesiology       reputation
# 4             60     5    Anesthesiology       reputation
# ..           ...   ...               ...              ...
# 72             5    73  Vascular Surgery  size-of-program
# 73             5    74  Vascular Surgery  size-of-program
# 74             5    75  Vascular Surgery  size-of-program
# 75             5    76  Vascular Surgery  size-of-program
# 76             5    77  Vascular Surgery  size-of-program
#
# [9419 rows x 6 columns]

# %%
df_complete[["specialty", "sort_by"]].value_counts()
# Out:
# specialty                             sort_by
# Family Medicine                       reputation         766
# Internal Medicine                     research-output    639
#                                       reputation         639
# Surgery                               research-output    358
#                                       reputation         358
# Psychiatry                            reputation         317
#                                       research-output    317
# Obstetrics and Gynecology             research-output    294
#                                       reputation         294
# Emergency Medicine                    research-output    286
#                                       reputation         286
# Pediatrics                            research-output    218
#                                       reputation         218
# Orthopaedic Surgery                   reputation         207
#                                       research-output    207
# Radiology-Diagnostic                  reputation         197
#                                       research-output    197
# Neurology                             reputation         183
#                                       research-output    183
# Anesthesiology                        research-output    172
#                                       reputation         172
# Urology                               research-output    150
#                                       reputation         150
# Dermatology                           research-output    143
#                                       reputation         143
# Pathology                             reputation         141
#                                       research-output    141
# Otolaryngology                        reputation         131
#                                       research-output    131
# Ophthalmology                         reputation         125
#                                       research-output    125
# Neurological Surgery                  research-output    118
#                                       reputation         118
# Physical Medicine and Rehabilitation  reputation         110
#                                       research-output    110
# Radiology-Interventional              size-of-program     96
# Plastic Surgery                       research-output     89
#                                       reputation          89
# Radiation Oncology                    research-output     88
#                                       reputation          88
# Child Neurology                       research-output     79
#                                       reputation          79
# Vascular Surgery                      size-of-program     77
# Internal Medicine-Pediatrics          reputation          77
#                                       research-output     77
# Pediatrics-Medical Genetics           size-of-program     47
# Preventive Medicine                   size-of-program     41
# Thoracic Surgery                      size-of-program     34
# Nuclear Medicine                      reputation          34
#                                       research-output     34
# Occupational Medicine                 research-output     23
#                                       reputation          23
# dtype: int64

# %%
# Exporting to excel doc
#df_complete.to_excel("tables/doximity_rankings.xlsx", index=False)

# %% [markdown]
# #### Test Code for above

# %%
soup = parse_dox(filename="dox_rankings/Internal Medicine_research-output.html")
#print(soup)

# %%
# Extracting the residency list div from the page
res_list = soup.find("div", class_ = "residency-program-list")

# %%
# Program names
programs = res_list.find_all("a", class_ = "residency-result-program-title")
programs = [p.text for p in programs]

# Program locations
locations = res_list.find_all("p", class_ = "residency-result-location")
locations = [l.text for l in locations]

# Program Sizes
program_size = res_list.find_all("p", class_ = "residency-result-stats-program-size")
program_size = [ps.text for ps in program_size]
pattern = r'\d+'
program_size = [int(re.findall(pattern, ps)[0]) for ps in program_size]

# Program ranks
ranks = np.arange(1, len(programs) + 1, 1)

# %%
# Making a dataframe
df = pd.DataFrame({"program": programs, "location": locations, "program_size": program_size, "rank": ranks})
df["specialty"] = "Anesthesiology"
df["sort_by"] = "reputation"
df
# Out:
#                                                program        location  \
# 0    Mass General Brigham/Massachusetts General Hos...          Boston
# 1    Mass General Brigham/Brigham and Women's Hospital          Boston
# 2             University of California (San Francisco)   San Francisco
# 3             University of Pennsylvania Health System    Philadelphia
# 4                             Johns Hopkins University       Baltimore
# ..                                                 ...             ...
# 634                       WakeMed Health and Hospitals         Raleigh
# 635                           Western Reserve Hospital  Cuyahoga Falls
# 636                      Willis-Knighton Health System      Shreveport
# 637  Zucker School of Medicine at Hofstra/Northwell...     Mount Kisco
# 638  Zucker School of Medicine at Hofstra/Northwell...       Bay Shore
#
#      program_size  rank       specialty     sort_by
# 0             168     1  Anesthesiology  reputation
# 1             174     2  Anesthesiology  reputation
# 2             185     3  Anesthesiology  reputation
# 3             182     4  Anesthesiology  reputation
# 4             145     5  Anesthesiology  reputation
# ..            ...   ...             ...         ...
# 634            15   635  Anesthesiology  reputation
# 635            18   636  Anesthesiology  reputation
# 636            30   637  Anesthesiology  reputation
# 637            32   638  Anesthesiology  reputation
# 638            18   639  Anesthesiology  reputation
#
# [639 rows x 6 columns]

# %% [markdown]
# ## **AAMC Table B4 Parser**
#
# Source: https://www.aamc.org/data-reports/students-residents/data/report-residents/2024/table-b4-md-phd-residents-gme-specialty

# %%
b4 = pd.read_excel("AAMC_data/AAMC_Table-B4.xlsx", sheet_name="table_b4")
b4 = b4.set_index("Specialties")
b4.head()
# Out:
#                                                       MD-PhD First-Year Residents 2016  \
# Specialties
# Aerospace Medicine                                                                 NaN
# Allergy and Immunology                                                             0.0
# Anesthesiology                                                                    16.0
# Adult Cardiothoracic Anesthesiology (Anesthesiology)                               0.0
# Critical Care Medicine (Anesthesiology)                                            0.0
#
#                                                       MD-PhD Active Residents 2016  \
# Specialties
# Aerospace Medicine                                                             NaN
# Allergy and Immunology                                                        15.0
# Anesthesiology                                                                90.0
# Adult Cardiothoracic Anesthesiology (Anesthesiology)                           5.0
# Critical Care Medicine (Anesthesiology)                                        3.0
#
#                                                       Total Active Residents 2016  \
# Specialties
# Aerospace Medicine                                                            NaN
# Allergy and Immunology                                                      212.0
# Anesthesiology                                                             4487.0
# Adult Cardiothoracic Anesthesiology (Anesthesiology)                        145.0
# Critical Care Medicine (Anesthesiology)                                     136.0
#
#                                                       MD-PhD First-Year Residents 2017  \
# Specialties
# Aerospace Medicine                                                                 NaN
# Allergy and Immunology                                                             0.0
# Anesthesiology                                                                    17.0
# Adult Cardiothoracic Anesthesiology (Anesthesiology)                               0.0
# Critical Care Medicine (Anesthesiology)                                            0.0
#
#                                                       MD-PhD Active Residents 2017  \
# Specialties
# Aerospace Medicine                                                             NaN
# Allergy and Immunology                                                        16.0
# Anesthesiology                                                                89.0
# Adult Cardiothoracic Anesthesiology (Anesthesiology)                           0.0
# Critical Care Medicine (Anesthesiology)                                        7.0
#
#                                                       Total Active Residents 2017  \
# Specialties
# Aerospace Medicine                                                            NaN
# Allergy and Immunology                                                      221.0
# Anesthesiology                                                             4444.0
# Adult Cardiothoracic Anesthesiology (Anesthesiology)                        136.0
# Critical Care Medicine (Anesthesiology)                                     131.0
#
#                                                       MD-PhD First-Year Residents 2018  \
# Specialties
# Aerospace Medicine                                                                 NaN
# Allergy and Immunology                                                             0.0
# Anesthesiology                                                                    14.0
# Adult Cardiothoracic Anesthesiology (Anesthesiology)                               0.0
# Critical Care Medicine (Anesthesiology)                                            0.0
#
#                                                       MD-PhD Active Residents 2018  \
# Specialties
# Aerospace Medicine                                                             NaN
# Allergy and Immunology                                                        17.0
# Anesthesiology                                                                81.0
# Adult Cardiothoracic Anesthesiology (Anesthesiology)                           2.0
# Critical Care Medicine (Anesthesiology)                                        6.0
#
#                                                       Total Active Residents 2018  \
# Specialties
# Aerospace Medicine                                                            NaN
# Allergy and Immunology                                                      221.0
# Anesthesiology                                                             4491.0
# Adult Cardiothoracic Anesthesiology (Anesthesiology)                        134.0
# Critical Care Medicine (Anesthesiology)                                     126.0
#
#                                                       MD-PhD First-Year Residents 2019  \
# Specialties
# Aerospace Medicine                                                                 NaN
# Allergy and Immunology                                                             1.0
# Anesthesiology                                                                    24.0
# Adult Cardiothoracic Anesthesiology (Anesthesiology)                               0.0
# Critical Care Medicine (Anesthesiology)                                            0.0
#
#                                                       ...  \
# Specialties                                           ...
# Aerospace Medicine                                    ...
# Allergy and Immunology                                ...
# Anesthesiology                                        ...
# Adult Cardiothoracic Anesthesiology (Anesthesiology)  ...
# Critical Care Medicine (Anesthesiology)               ...
#
#                                                       Total Active Residents 2020  \
# Specialties
# Aerospace Medicine                                                            NaN
# Allergy and Immunology                                                      224.0
# Anesthesiology                                                             4441.0
# Adult Cardiothoracic Anesthesiology (Anesthesiology)                        147.0
# Critical Care Medicine (Anesthesiology)                                     130.0
#
#                                                       MD-PhD First-Year Residents 2021  \
# Specialties
# Aerospace Medicine                                                                 0.0
# Allergy and Immunology                                                             0.0
# Anesthesiology                                                                    14.0
# Adult Cardiothoracic Anesthesiology (Anesthesiology)                               0.0
# Critical Care Medicine (Anesthesiology)                                            0.0
#
#                                                       MD-PhD Active Residents 2021  \
# Specialties
# Aerospace Medicine                                                             1.0
# Allergy and Immunology                                                        20.0
# Anesthesiology                                                                90.0
# Adult Cardiothoracic Anesthesiology (Anesthesiology)                           6.0
# Critical Care Medicine (Anesthesiology)                                        5.0
#
#                                                       Total Active Residents 2021  \
# Specialties
# Aerospace Medicine                                                            7.0
# Allergy and Immunology                                                      236.0
# Anesthesiology                                                             4795.0
# Adult Cardiothoracic Anesthesiology (Anesthesiology)                        141.0
# Critical Care Medicine (Anesthesiology)                                     140.0
#
#                                                       MD-PhD First-Year Residents 2022  \
# Specialties
# Aerospace Medicine                                                                 0.0
# Allergy and Immunology                                                             0.0
# Anesthesiology                                                                    18.0
# Adult Cardiothoracic Anesthesiology (Anesthesiology)                               0.0
# Critical Care Medicine (Anesthesiology)                                            0.0
#
#                                                       MD-PhD Active Residents 2022  \
# Specialties
# Aerospace Medicine                                                             2.0
# Allergy and Immunology                                                        22.0
# Anesthesiology                                                                94.0
# Adult Cardiothoracic Anesthesiology (Anesthesiology)                           3.0
# Critical Care Medicine (Anesthesiology)                                        3.0
#
#                                                       Total Active Residents 2022  \
# Specialties
# Aerospace Medicine                                                            5.0
# Allergy and Immunology                                                      240.0
# Anesthesiology                                                             4969.0
# Adult Cardiothoracic Anesthesiology (Anesthesiology)                        149.0
# Critical Care Medicine (Anesthesiology)                                     142.0
#
#                                                       MD-PhD First-Year Residents 2023  \
# Specialties
# Aerospace Medicine                                                                 0.0
# Allergy and Immunology                                                             0.0
# Anesthesiology                                                                    14.0
# Adult Cardiothoracic Anesthesiology (Anesthesiology)                               0.0
# Critical Care Medicine (Anesthesiology)                                            0.0
#
#                                                       MD-PhD Active Residents 2023  \
# Specialties
# Aerospace Medicine                                                             1.0
# Allergy and Immunology                                                        22.0
# Anesthesiology                                                                92.0
# Adult Cardiothoracic Anesthesiology (Anesthesiology)                           2.0
# Critical Care Medicine (Anesthesiology)                                        5.0
#
#                                                       Total Active Residents 2023
# Specialties
# Aerospace Medicine                                                            4.0
# Allergy and Immunology                                                      228.0
# Anesthesiology                                                             5209.0
# Adult Cardiothoracic Anesthesiology (Anesthesiology)                        135.0
# Critical Care Medicine (Anesthesiology)                                     127.0
#
# [5 rows x 24 columns]

# %%
# Formatting to long format per year
year_list = ["2016", "2017", "2018", "2019", "2020", "2021", "2022", "2023"]
b4_list = []
for year in year_list:
    b4_filt = b4.filter(like=year, axis=1).reset_index()
    b4_filt.columns = ["specialties", "mdphd_firstyear", "mdphd_active", "total_active"]
    b4_filt["year"] = int(year)
    b4_list.append(b4_filt)
b4_complete = pd.concat(b4_list)
b4_complete
# Out:
#                                                specialties  mdphd_firstyear  \
# 0                                       Aerospace Medicine              NaN
# 1                                   Allergy and Immunology              0.0
# 2                                           Anesthesiology             16.0
# 3     Adult Cardiothoracic Anesthesiology (Anesthesiology)              0.0
# 4                  Critical Care Medicine (Anesthesiology)              0.0
# ..                                                     ...              ...
# 160        Pediatrics/Physical Medicine and Rehabilitation              0.0
# 161  Pediatrics/Psychiatry/Child and Adolescent Psychiatry              0.0
# 162                             Psychiatry/Family Practice              0.0
# 163                                   Psychiatry/Neurology              NaN
# 164                                                  Total            576.0
#
#      mdphd_active  total_active  year
# 0             NaN           NaN  2016
# 1            15.0         212.0  2016
# 2            90.0        4487.0  2016
# 3             5.0         145.0  2016
# 4             3.0         136.0  2016
# ..            ...           ...   ...
# 160           1.0          11.0  2023
# 161           2.0          97.0  2023
# 162           1.0          49.0  2023
# 163           NaN           NaN  2023
# 164        2982.0       92276.0  2023
#
# [1320 rows x 5 columns]

# %%
# Exporting to excel
#b4_complete.to_excel("AAMC_data/AAMC_Table-B4_processed.xlsx", index=False)
